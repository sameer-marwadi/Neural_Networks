# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout, BatchNormalization
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

# %% [markdown]
# # Set seed for reprodicibility

# %%
np.random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# # Load the Fashion-MNIST dataset

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 1us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 1us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# X_train shape: (60000, 28, 28)
# X_test shape: (10000, 28, 28)
# y_train shape: (60000,)

# %% [markdown]
# # Class names

# %%
class_names = [
    'T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
    'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot'
]

print(class_names)
# Out:
# ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %% [markdown]
# # Visualize some Sample images

# %%
plt.figure(figsize=(10, 5))
for i in range(10):
    plt.subplot(2, 5, i + 1)
    plt.imshow(X_train[i], cmap='gray')
    plt.title(class_names[y_train[i]])
    plt.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Normalize the image data

# %% [markdown]
# ##### Pixel values originally range from 0 to 255.
# ##### We scale them to the range [0, 1].

# %%
X_train = X_train.astype("float32") / 255.0
X_test = X_test.astype("float32") / 255.0

print("Min pixel value:", X_train.min())
print("Max pixel value:", X_train.max())
# Out:
# Min pixel value: 0.0
# Max pixel value: 1.0

# %% [markdown]
# # Build the DNN model
# ##### This is a fully connected deep neural network, not a CNN, so it is ideal if you want to specifically assess a standard DNN.

# %%
model = Sequential([
    Flatten(input_shape=(28, 28)),

    Dense(256, activation='relu', kernel_regularizer=l2(0.001)),
    BatchNormalization(),
    Dropout(0.4),

    Dense(128, activation='relu', kernel_regularizer=l2(0.001)),
    BatchNormalization(),
    Dropout(0.3),

    Dense(64, activation='relu', kernel_regularizer=l2(0.001)),
    BatchNormalization(),
    Dropout(0.2),

    Dense(10, activation='softmax')
])

model.summary()
# Out:
# C:\Users\12146\anaconda3\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)                    │ (None, 784)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │         200,960 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 64)                  │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 10)                  │             650 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 244,554 (955.29 KB)
#  Trainable params: 243,658 (951.79 KB)
#  Non-trainable params: 896 (3.50 KB)

# %% [markdown]
# # Compile the model
# ##### Because this is multiclass classification, we use:
# ##### sparse_categorical_crossentropy
# ##### accuracy

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# # Early stopping

# %%
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True,
    verbose=1
)

# %% [markdown]
# # Train the model

# %%
history = model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=50,
    batch_size=128,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 20s 35ms/step - accuracy: 0.7577 - loss: 1.2167 - val_accuracy: 0.8345 - val_loss: 0.8987
# Epoch 2/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 13s 34ms/step - accuracy: 0.8204 - loss: 0.8808 - val_accuracy: 0.8438 - val_loss: 0.7482
# Epoch 3/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 22s 37ms/step - accuracy: 0.8305 - loss: 0.7500 - val_accuracy: 0.8407 - val_loss: 0.6606
# Epoch 4/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 11s 28ms/step - accuracy: 0.8367 - loss: 0.6615 - val_accuracy: 0.8537 - val_loss: 0.5805
# Epoch 5/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 13s 35ms/step - accuracy: 0.8391 - loss: 0.6136 - val_accuracy: 0.8354 - val_loss: 0.5814
# Epoch 6/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 12s 31ms/step - accuracy: 0.8382 - loss: 0.5865 - val_accuracy: 0.8466 - val_loss: 0.5442
# Epoch 7/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 26s 46ms/step - accuracy: 0.8417 - loss: 0.5602 - val_accuracy: 0.8523 - val_loss: 0.5305
# Epoch 8/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 18s 39ms/step - accuracy: 0.8420 - loss: 0.5512 - val_accuracy: 0.8654 - val_loss: 0.4878
# Epoch 9/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 13s 34ms/step - accuracy: 0.8447 - loss: 0.5356 - val_accuracy: 0.8631 - val_loss: 0.4813
# Epoch 10/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 27s 51ms/step - accuracy: 0.8439 - loss: 0.5341 - val_accuracy: 0.8548 - val_loss: 0.4967
# Epoch 11/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 16s 39ms/step - accuracy: 0.8468 - loss: 0.5243 - val_accuracy: 0.8413 - val_loss: 0.5697
# Epoch 12/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 15s 39ms/step - accuracy: 0.8434 - loss: 0.5295 - val_accuracy: 0.8455 - val_loss: 0.5034
# Epoch 13/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 20s 37ms/step - accuracy: 0.8460 - loss: 0.5232 - val_accuracy: 0.8602 - val_loss: 0.4879
# Epoch 14/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 21s 37ms/step - accuracy: 0.8464 - loss: 0.5262 - val_accuracy: 0.8415 - val_loss: 0.5246
# Epoch 15/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 22s 40ms/step - accuracy: 0.8469 - loss: 0.5254 - val_accuracy: 0.8518 - val_loss: 0.4992
# Epoch 16/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 19s 36ms/step - accuracy: 0.8474 - loss: 0.5199 - val_accuracy: 0.8450 - val_loss: 0.5104
# Epoch 17/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 27s 53ms/step - accuracy: 0.8497 - loss: 0.5136 - val_accuracy: 0.8516 - val_loss: 0.4924
# Epoch 18/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 15s 39ms/step - accuracy: 0.8471 - loss: 0.5155 - val_accuracy: 0.8582 - val_loss: 0.4820
# Epoch 19/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 18s 32ms/step - accuracy: 0.8480 - loss: 0.5055 - val_accuracy: 0.8624 - val_loss: 0.4638
# Epoch 20/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 21s 32ms/step - accuracy: 0.8480 - loss: 0.5114 - val_accuracy: 0.8568 - val_loss: 0.4940
# Epoch 21/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 24s 43ms/step - accuracy: 0.8472 - loss: 0.5141 - val_accuracy: 0.8614 - val_loss: 0.4707
# Epoch 22/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 21s 57ms/step - accuracy: 0.8481 - loss: 0.5089 - val_accuracy: 0.8531 - val_loss: 0.5035
# Epoch 23/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 49s 77ms/step - accuracy: 0.8516 - loss: 0.5081 - val_accuracy: 0.8588 - val_loss: 0.4762
# Epoch 24/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 31s 49ms/step - accuracy: 0.8489 - loss: 0.5103 - val_accuracy: 0.8577 - val_loss: 0.4804
# Epoch 25/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 16s 36ms/step - accuracy: 0.8493 - loss: 0.5043 - val_accuracy: 0.8645 - val_loss: 0.4748
# Epoch 26/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 19s 31ms/step - accuracy: 0.8508 - loss: 0.5023 - val_accuracy: 0.8636 - val_loss: 0.4567
# Epoch 27/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 22s 36ms/step - accuracy: 0.8530 - loss: 0.4986 - val_accuracy: 0.8648 - val_loss: 0.4580
# Epoch 28/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 12s 32ms/step - accuracy: 0.8486 - loss: 0.5044 - val_accuracy: 0.8551 - val_loss: 0.4996
# Epoch 29/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 21s 32ms/step - accuracy: 0.8511 - loss: 0.5063 - val_accuracy: 0.8526 - val_loss: 0.4860
# Epoch 30/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 12s 31ms/step - accuracy: 0.8510 - loss: 0.5064 - val_accuracy: 0.8581 - val_loss: 0.4765
# Epoch 31/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 22s 34ms/step - accuracy: 0.8530 - loss: 0.5027 - val_accuracy: 0.8558 - val_loss: 0.4806
# Epoch 32/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 13s 34ms/step - accuracy: 0.8527 - loss: 0.4976 - val_accuracy: 0.8378 - val_loss: 0.5020
# Epoch 33/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 19s 30ms/step - accuracy: 0.8512 - loss: 0.4991 - val_accuracy: 0.8577 - val_loss: 0.4752
# Epoch 34/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 30s 54ms/step - accuracy: 0.8503 - loss: 0.5006 - val_accuracy: 0.8573 - val_loss: 0.4778
# Epoch 35/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 15s 38ms/step - accuracy: 0.8535 - loss: 0.4976 - val_accuracy: 0.8538 - val_loss: 0.4781
# Epoch 36/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 20s 36ms/step - accuracy: 0.8509 - loss: 0.4968 - val_accuracy: 0.8464 - val_loss: 0.5068
# Epoch 36: early stopping
# Restoring model weights from the end of the best epoch: 26.

# %% [markdown]
# # Plot Training History

# %%
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # Evaluate on Test Data

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=0)

print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
# Out:
# Test Loss: 0.4825
# Test Accuracy: 0.8540

# %% [markdown]
# # Make Predictions

# %%
y_pred_prob = model.predict(X_test)
y_pred = np.argmax(y_pred_prob, axis=1)

print("First 10 predicted labels:", y_pred[:10])
print("First 10 true labels:     ", y_test[:10])
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step
# First 10 predicted labels: [9 2 1 1 6 1 4 6 5 7]
# First 10 true labels:      [9 2 1 1 6 1 4 6 5 7]

# %% [markdown]
# # classification Report

# %%
print(classification_report(y_test, y_pred, target_names=class_names))
# Out:
#               precision    recall  f1-score   support
#
#  T-shirt/top       0.81      0.82      0.81      1000
#      Trouser       0.98      0.97      0.97      1000
#     Pullover       0.76      0.75      0.76      1000
#        Dress       0.88      0.86      0.87      1000
#         Coat       0.68      0.86      0.76      1000
#       Sandal       0.96      0.95      0.95      1000
#        Shirt       0.69      0.48      0.56      1000
#      Sneaker       0.94      0.92      0.93      1000
#          Bag       0.91      0.97      0.94      1000
#   Ankle boot       0.93      0.96      0.94      1000
#
#     accuracy                           0.85     10000
#    macro avg       0.85      0.85      0.85     10000
# weighted avg       0.85      0.85      0.85     10000

# %% [markdown]
# # Confusion Matrix

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix - Fashion MNIST")
plt.show()

# %% [markdown]
# # Show some correct and incorrect predictions

# %%
plt.figure(figsize=(12, 8))
for i in range(15):
    plt.subplot(3, 5, i + 1)
    plt.imshow(X_test[i], cmap='gray')
    pred_label = class_names[y_pred[i]]
    true_label = class_names[y_test[i]]
    plt.title(f"P: {pred_label}\nT: {true_label}")
    plt.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Save the Model

# %%
model.save("fashion_mnist_dnn_model.h5")
print("Fashion-MNIST model saved successfully.")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Fashion-MNIST model saved successfully.
